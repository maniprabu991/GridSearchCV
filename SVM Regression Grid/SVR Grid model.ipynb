# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True).astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
              'C':[10,100,1000,2000,3000],
              'gamma':['auto','scale']
             }


grid = GridSearchCV(SVR(), param_grid, verbose =3, n_jobs= -1)

grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
result=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.214423      0.101885         0.105613    6.143679e-02      10
# 1        0.185620      0.078457         0.028804    1.933535e-02      10
# 2        0.179220      0.013951         0.044805    1.866024e-02      10
# 3        0.113611      0.017818         0.020803    6.403017e-03      10
# 4        0.136016      0.016002         0.067212    1.647372e-02      10
# 5        0.113613      0.010615         0.019202    8.159813e-03      10
# 6        0.156817      0.016477         0.032004    5.061238e-03      10
# 7        0.115214      0.011975         0.019203    3.920360e-03      10
# 8        0.140813      0.006401         0.057607    3.200294e-03     100
# 9        0.128014      0.008765         0.025604    1.280071e-02     100
# 10       0.169616      0.010615         0.030405    3.200365e-03     100
# 11       0.144014      0.013387         0.019204    3.919367e-03     100
# 12       0.150417      0.011762         0.065607    3.200531e-03     100
# 13       0.124815      0.006402         0.020802    6.399226e-03     100
# 14       0.152017      0.010122         0.036803    9.601069e-03     100
# 15       0.129614      0.009329         0.024006    7.156019e-03     100
# 16       0.182419      0.013766         0.056006    8.765059e-03    1000
# 17       0.184019      0.017528         0.022403    7.839084e-03    1000
# 18       0.171218      0.013001         0.032003    5.060408e-03    1000
# 19       0.169618      0.012802         0.017602    3.201509e-03    1000
# 20       0.169618      0.003200         0.060806    3.921373e-03    1000
# 21       0.171219      0.013949         0.020802    3.921100e-03    1000
# 22       0.188820      0.013950         0.027205    6.400919e-03    1000
# 23       0.174416      0.003201         0.016004    5.059504e-03    1000
# 24       0.195221      0.011975         0.056006    5.060334e-03    2000
# 25       0.296030      0.087646         0.024003    7.156978e-03    2000
# 26       0.174417      0.005986         0.027205    8.160262e-03    2000
# 27       0.216022      0.014314         0.019204    3.918881e-03    2000
# 28       0.195221      0.006402         0.060807    9.602666e-03    2000
# 29       0.268828      0.099366         0.016002    5.060333e-03    2000
# 30       0.126413      0.005987         0.016002    7.156658e-03    2000
# 31       0.137614      0.009331         0.011203    3.919270e-03    2000
# 32       0.140814      0.010854         0.040005    5.060786e-03    3000
# 33       0.270431      0.048377         0.012802    3.919931e-03    3000
# 34       0.156818      0.009601         0.025602    5.986945e-03    3000
# 35       0.211222      0.008160         0.016002    4.422006e-07    3000
# 36       0.187221      0.013000         0.052806    6.400001e-03    3000
# 37       0.393644      0.122955         0.017601    3.200102e-03    3000
# 38       0.148817      0.008160         0.028804    3.919523e-03    3000
# 39       0.219224      0.008160         0.016001    1.093611e-06    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.003851
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.047251
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.044671
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.387781
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.003630
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.043592
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.043832
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.387781
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.303052
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.538805
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.491184
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.596323
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.304603
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.529111
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.491961
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.596323
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.732235
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.802150
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.213778
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.686071
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733100
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.800138
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.230557
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.686071
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.790350
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.807373
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.428467
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.669872
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.790469
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.807166
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.365255
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.669872
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.798285
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.807076
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.713943
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.669787
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.798438
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.806961
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.588530
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.669787
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.022547          -0.119145          -0.082937
# 1            0.077503          -0.060846          -0.009857
# 2            0.081834          -0.071985          -0.027577
# 3            0.461320           0.288340           0.340375
# 4            0.022403          -0.119220          -0.082931
# 5            0.079791          -0.059413          -0.009975
# 6            0.082386          -0.071789          -0.027601
# 7            0.461320           0.288340           0.340375
# 8            0.318979           0.155994           0.208295
# 9            0.565393           0.468291           0.535660
# 10           0.545823           0.440857           0.468358
# 11           0.635951           0.567191           0.589008
# 12           0.318027           0.155504           0.208340
# 13           0.570831           0.471578           0.535354
# 14           0.545117           0.442379           0.468142
# 15           0.635951           0.567191           0.589008
# 16           0.717366           0.687699           0.708644
# 17           0.788345           0.823416           0.809351
# 18           0.386171           0.247488           0.299904
# 19           0.598372           0.585612           0.574003
# 20           0.717065           0.687198           0.708674
# 21           0.788383           0.824731           0.809304
# 22           0.378398           0.314279           0.285273
# 23           0.598372           0.585612           0.574003
# 24           0.763325           0.818891           0.793540
# 25           0.784799           0.846895           0.805925
# 26          -0.398709          -0.357990          -0.477094
# 27           0.592478           0.587021           0.573207
# 28           0.763233           0.818659           0.793550
# 29           0.784663           0.847066           0.805942
# 30          -0.644413          -0.371621          -0.476729
# 31           0.592478           0.587021           0.573207
# 32           0.773767           0.845056           0.810145
# 33           0.784421           0.850442           0.809372
# 34          -1.598228          -1.617188          -1.703189
# 35           0.589184           0.587209           0.573073
# 36           0.773660           0.844961           0.810150
# 37           0.784262           0.850520           0.809370
# 38          -2.124473          -1.645852          -1.699789
# 39           0.589184           0.587209           0.573073
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.103704        -0.057418        0.056334               35
# 1           -0.050652         0.000680        0.054041               32
# 2           -0.051505        -0.004912        0.058595               34
# 3            0.297979         0.355159        0.063698               25
# 4           -0.103746        -0.057425        0.056358               36
# 5           -0.050056         0.000788        0.053663               31
# 6           -0.051349        -0.004904        0.058550               33
# 7            0.297979         0.355159        0.063698               25
# 8            0.161274         0.229519        0.069172               29
# 9            0.413862         0.504402        0.055465               22
# 10           0.426051         0.474455        0.042148               24
# 11           0.537276         0.585150        0.032665               19
# 12           0.160976         0.229490        0.069421               30
# 13           0.415812         0.504537        0.054602               21
# 14           0.426208         0.474761        0.041703               23
# 15           0.537276         0.585150        0.032665               19
# 16           0.612031         0.691595        0.042313               11
# 17           0.724014         0.789455        0.034624                7
# 18           0.345714         0.298611        0.062765               28
# 19           0.555807         0.599973        0.045270               13
# 20           0.611847         0.691577        0.042526               12
# 21           0.724383         0.789388        0.034606                8
# 22           0.344756         0.310652        0.050646               27
# 23           0.555807         0.599973        0.045270               13
# 24           0.706236         0.774468        0.038390                9
# 25           0.746230         0.798244        0.032850                3
# 26          -0.082734        -0.348999        0.138689               37
# 27           0.555837         0.595683        0.039197               15
# 28           0.706091         0.774400        0.038405               10
# 29           0.746230         0.798213        0.032901                4
# 30          -0.079157        -0.387435        0.184276               38
# 31           0.555837         0.595683        0.039197               15
# 32           0.725875         0.790625        0.039697                5
# 33           0.750276         0.800317        0.032854                2
# 34          -0.943727        -1.515255        0.289384               39
# 35           0.557785         0.595407        0.038865               17
# 36           0.725785         0.790599        0.039716                6
# 37           0.750629         0.800348        0.032781                1
# 38          -0.933053        -1.598339        0.382640               40
# 39           0.557785         0.595407        0.038865               17

# %%
Age_input=float(input("Age:"))
BMI_input=float(input("BMI:"))
Child_input=float(input("Children:"))
Gender_input=int(input("Sex Male 0 or 1:"))
Smoker_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:43
# BMI:56
# Children:1
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
F_Prediction=grid.predict([[Age_input,BMI_input,Child_input,Gender_input,Smoker_input]])
print("Future_Prediction={}".format(F_Prediction))
# Out:
# Future_Prediction=[12002350.04523222]
